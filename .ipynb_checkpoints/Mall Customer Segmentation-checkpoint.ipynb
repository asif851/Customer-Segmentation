# %%
# import liabrary

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %matplotlib inline

# %%
# import dataset

df=pd.read_csv('Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# drop unnecessary column

df.drop('CustomerID',axis=1,inplace=True)
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  200 non-null    object
#  1   Age                     200 non-null    int64
#  2   Annual Income (k$)      200 non-null    int64
#  3   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %% [markdown]
# Note: Dataset does not have any Null Value

# %%
df.describe()
# Out:
#               Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000          200.000000              200.000000
# mean    38.850000           60.560000               50.200000
# std     13.969007           26.264721               25.823522
# min     18.000000           15.000000                1.000000
# 25%     28.750000           41.500000               34.750000
# 50%     36.000000           61.500000               50.000000
# 75%     49.000000           78.000000               73.000000
# max     70.000000          137.000000               99.000000

# %%
sns.heatmap(df.corr() , annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
df['Gender'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Gender, dtype: int64

# %%
sns.countplot('Gender',data=df)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
labels = ['Female', 'Male']
size = df['Gender'].value_counts()
colors = ['lightseagreen', 'orange']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (7, 7)
plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Gender', fontsize = 10)
plt.axis('off')
plt.legend()
plt.show()

# %%
sns.boxplot(x='Gender',y='Annual Income (k$)',data=df,palette='muted')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Annual Income (k$)'>

# %%
sns.boxplot(x='Gender',y='Spending Score (1-100)',data=df,palette='muted')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Spending Score (1-100)'>

# %%
df.head(2)
# Out:
#   Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0   Male   19                  15                      39
# 1   Male   21                  15                      81

# %%
sns.histplot(x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x='Age',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.relplot(x='Age',y='Annual Income (k$)',data=df,hue='Gender',kind='scatter')
plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
# Out:
# Text(28.96328125, 0.5, 'Annual Income (k$)')

# %%
sns.relplot(x='Age',y='Spending Score (1-100)',data=df,hue='Gender',kind='scatter')
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
# Out:
# Text(28.93919270833333, 0.5, 'Spending Score (1-100)')

# %%
sns.relplot(x='Annual Income (k$)',y='Spending Score (1-100)',data=df,kind='scatter')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
# Out:
# Text(4.050000000000004, 0.5, 'Spending Score (1-100)')

# %%
sns.relplot(x='Annual Income (k$)',y='Spending Score (1-100)',data=df,hue='Gender',kind='scatter')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
# Out:
# Text(28.93919270833333, 0.5, 'Spending Score (1-100)')

# %%
df.head(2)
# Out:
#   Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0   Male   19                  15                      39
# 1   Male   21                  15                      81

# %% [markdown]
# # K-Means Clusturning

# %%
# 0 represents Male
# 1 represents Female

df['Gender'].replace({'Male':0,'Female':1},inplace=True)

# %%
df['Gender'].dtype
# Out:
# dtype('int64')

# %%
from sklearn.cluster import KMeans

# %%
# label encoding 

from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()

# %%
lst = []
for i in range(1,11):
    k_model= KMeans(n_clusters = i, n_init = 15, max_iter = 500) 
    k_model.fit(df)
    lst.append(k_model.inertia_)

# %%
lst
# Out:
# [308862.06000000006,
#  212889.44245524294,
#  143391.59236035674,
#  104414.67534220174,
#  75399.61541401486,
#  58348.64136331505,
#  51130.690081263754,
#  44687.23553400544,
#  40693.47096922684,
#  37132.84983602549]

# %%
plt.plot(range(1,11), lst, marker = 'o')
plt.title('Elbow Theroy',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Elbow Theroy')

# %%
k_model = KMeans(n_clusters = 5)

# %% [markdown]
# Note: Used 5 rather than 6 beacuse of better clustering result

# %%
k_model.fit(df)
# Out:
# KMeans(n_clusters=5)

# %%
prediction = k_model.predict(df)

# %%
k_model.cluster_centers_
# Out:
# array([[ 0.53846154, 32.69230769, 86.53846154, 82.12820513],
#        [ 0.60869565, 45.2173913 , 26.30434783, 20.91304348],
#        [ 0.47222222, 40.66666667, 87.75      , 17.58333333],
#        [ 0.60869565, 25.52173913, 26.30434783, 78.56521739],
#        [ 0.58227848, 43.08860759, 55.29113924, 49.56962025]])

# %%
len(k_model.cluster_centers_)
# Out:
# 5

# %%
df['Clusters'] = prediction

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)  Clusters
# 0    Male   19                  15                      39         1
# 1    Male   21                  15                      81         3
# 2  Female   20                  16                       6         1
# 3  Female   23                  16                      77         3
# 4  Female   31                  17                      40         1

# %%
color = np.array(['red','blue', 'yellow', 'green', 'black'])
sns.scatterplot(x = df['Annual Income (k$)'], y = df['Spending Score (1-100)'], c = color[k_model.labels_], s = 50)
# Out:
# <AxesSubplot:xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %% [raw]
# Clusters:
#
# Cluster 0 : Upper-Middle Income, High Spending Score
# Cluster 1 : Low Income, Low Spending Score
# Cluster 2 : Upper-Middle Income, Low Spending Score
# Cluster 3 : Low Income, High Spending Score
# Cluster 4 : Middle Income, Middle Spending Score
